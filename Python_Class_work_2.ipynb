# %%
x=10+5
y=5+20
name1= "irsham"
print(name1)
print(x)
print(y)
# Out:
# irsham
# 15
# 25

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
y='irsham'
print(type(y))
# Out:
# <class 'str'>

# %%
z=2.34
print(type(z))
# Out:
# <class 'float'>

# %%
is_road_closed=True
print(type(is_road_closed))
# Out:
# <class 'bool'>

# %%
x=int(input('Enter the value'))
print(x)
print(type(x))
# Out:
# Enter the value 100
# 100
# <class 'int'>

# %%
x=7
y=4
print(x+y)
print(x-y)
# Out:
# 11
# 3
